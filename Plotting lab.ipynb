# %%
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

# Download the data, save to a file called "housing.data"
import urllib
data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"
urllib.urlretrieve (data_url, "housing.data")
# Out:
# ('housing.data', <httplib.HTTPMessage instance at 0x10a3bdcb0>)

# %%
names = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE",
         "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]

# %%
import pandas as pd

data = pd.read_csv("housing.data", header=None, names=names, delim_whitespace=True)

# Take a look at the first few rows
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
subset = data['MEDV', 'LSTAT', 'RM', 'PRATIO', 'TAX', 'NOX']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-7ba1a9ba976e> in <module>()
# ----> 1 subset = data['MEDV', 'LSTAT', 'RM', 'PRATIO', 'TAX', 'NOX']
#
# /Users/christophereppig/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/christophereppig/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
import seaborn as sns

# Plot using pandas
data.plot.scatter(x='CRIM', y='MEDV')

# %%
np.corrcoef(data['CRIM'], data['MEDV'])
# Out:
# array([[ 1.        , -0.38830461],
#        [-0.38830461,  1.        ]])

# %%
data.plot.scatter(x='ZN', y='MEDV')

# %%
np.corrcoef(data['ZN'], data['MEDV'])
# Out:
# array([[ 1.        ,  0.36044534],
#        [ 0.36044534,  1.        ]])

# %%
data.plot.scatter(x='INDUS', y='MEDV')

# %%
np.corrcoef(data['INDUS'], data['MEDV'])
# Out:
# array([[ 1.        , -0.48372516],
#        [-0.48372516,  1.        ]])

# %%
data.plot.scatter(x='CHAS', y='MEDV')

# %%
np.corrcoef(data['CHAS'], data['MEDV'])
# Out:
# array([[ 1.        ,  0.17526018],
#        [ 0.17526018,  1.        ]])

# %%
data.plot.scatter(x='PTRATIO', y='CRIM')

# %%
np.corrcoef(data['NOX'], data['MEDV'])
# Out:
# array([[ 1.        , -0.42732077],
#        [-0.42732077,  1.        ]])

# %%
data.plot.scatter(x='RM', y='MEDV')

# %%
np.corrcoef(data['RM'], data['MEDV'])
# Out:
# array([[ 1.        ,  0.69535995],
#        [ 0.69535995,  1.        ]])

# %%
data.plot.scatter(x='AGE', y='MEDV')

# %%
np.corrcoef(data['AGE'], data['MEDV'])
# Out:
# array([[ 1.        , -0.37695457],
#        [-0.37695457,  1.        ]])

# %%
data.plot.scatter(x='DIS', y='MEDV')

# %%
np.corrcoef(data['DIS'], data['MEDV'])
# Out:
# array([[ 1.        ,  0.24992873],
#        [ 0.24992873,  1.        ]])

# %%
data.plot.scatter(x='RAD', y='MEDV')

# %%
np.corrcoef(data['RAD'], data['MEDV'])
# Out:
# array([[ 1.        , -0.38162623],
#        [-0.38162623,  1.        ]])

# %%
data.plot.scatter(x='TAX', y='MEDV')

# %%
np.corrcoef(data['TAX'], data['MEDV'])
# Out:
# array([[ 1.        , -0.46853593],
#        [-0.46853593,  1.        ]])

# %%
data.plot.scatter(x='PTRATIO', y='MEDV')

# %%
np.corrcoef(data['PTRATIO'], data['MEDV'])
# Out:
# array([[ 1.        , -0.50778669],
#        [-0.50778669,  1.        ]])

# %%
data.plot.scatter(x='B', y='MEDV')

# %%
np.corrcoef(data['B'], data['MEDV'])
# Out:
# array([[ 1.        ,  0.33346082],
#        [ 0.33346082,  1.        ]])

# %%
data.plot.scatter(x='LSTAT', y='MEDV')

# %%
np.corrcoef(data['LSTAT'], data['MEDV'])
# Out:
# array([[ 1.        , -0.73766273],
#        [-0.73766273,  1.        ]])

# %%
sns.pairplot(data, vars=["LSTAT", 'B', 'DIS', 'PTRATIO', 'NOX', 'CRIM'])
